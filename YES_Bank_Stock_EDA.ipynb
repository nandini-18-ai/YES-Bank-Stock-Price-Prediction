# %% [markdown]
# # **Project Name**    -**YES Bank Stock Price Exploratory Data Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name** - Nandini Dhole

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The YES Bank Stock Price Exploratory Data Analysis project focuses on analyzing the historical monthly stock price data of YES Bank to understand price movements, market trends, volatility, and relationships among important stock market variables.
# The project analyzes historical monthly data—comprising Date, Open, High, Low, and Close variables.
# The primary objective of this exploratory data analysis is to extract meaningful insights from historical stock data and identify the factors that are closely associated with the closing price of YES Bank stock.
# The dataset contains monthly stock price records with five major variables: Date, Open, High, Low, and Close. The Date variable represents the month and year of each stock price observation. Open represents the opening stock price, High represents the highest stock price recorded during the period, Low represents the lowest stock price, and Close represents the final closing price. The Close variable is particularly important because it reflects the final market valuation of the stock for a given period.
# The analysis begins by understanding the structure and characteristics of the dataset. The number of rows and columns, data types, missing values, duplicate records, and descriptive statistics are examined to evaluate data quality. The Date column is converted into datetime format to enable chronological analysis of stock price movements. Additional time-based features such as Year and Month can be extracted to support trend analysis.
# Data wrangling techniques are applied to prepare the dataset for analysis. Missing values and duplicate records are checked, and the numerical variables are examined for unusual observations and potential outliers. Statistical summaries are used to understand the central tendency, spread, minimum, and maximum values of the stock price variables.
# Different data visualization techniques are used to perform univariate, bivariate, and multivariate analysis. Univariate analysis is performed to understand the distribution of individual stock variables such as Open, High, Low, and Close prices. Bivariate analysis is used to study relationships between variables, particularly the relationship between opening price and closing price, high price and closing price, and low price and closing price. Multivariate analysis and correlation analysis are used to understand the combined relationships among multiple stock price variables.
# Time-series visualizations are used to analyze historical movements in YES Bank's closing price and identify periods of significant price growth or decline. Distribution plots, box plots, scatter plots, line charts, and correlation heatmaps help reveal patterns in stock price behaviour and market volatility. The analysis indicates that Open, High, and Low prices have strong relationships with the closing price and therefore provide important information for understanding stock price movements.
# The insights obtained from the exploratory data analysis can support investors, financial analysts, and decision-makers in understanding historical stock behaviour. Identifying price trends, volatility patterns, and relationships between stock variables can contribute to more informed financial analysis and data-driven decision-making.
# Overall, this exploratory data analysis provides a comprehensive understanding of the YES Bank stock price dataset. The findings and visual insights generated during the analysis establish a strong foundation for further predictive modelling and machine learning applications for stock closing price prediction.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# YES Bank is a well-known private sector bank in India whose stock price has experienced significant fluctuations over time. Understanding historical stock price movements and the relationships among opening, high, low, and closing prices is important for financial analysis and informed decision-making.
#
# The objective of this project is to perform exploratory data analysis on the historical monthly stock price data of YES Bank to identify trends, patterns, price volatility, and relationships among different stock price variables. The analysis aims to generate meaningful insights that can support a better understanding of the factors associated with the closing price of YES Bank stock.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective is to analyze the historical stock price behaviour of YES Bank and identify significant trends, volatility patterns, and relationships among Open, High, Low, and Close prices.
#
# The analysis aims to provide meaningful data-driven insights that can help investors, financial analysts, and other stakeholders better understand historical stock price movements and support informed financial analysis and decision-making. The insights obtained from the exploratory data analysis can also provide a foundation for developing predictive machine learning models for stock closing price prediction.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/ML_Project/data_YesBank_StockPrices.csv')

print("Dataset loaded successfully.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset loaded successfully.

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

df.head()
# Out:
#      Date   Open   High    Low  Close
# 0  Jul-05  13.00  14.00  11.25  12.46
# 1  Aug-05  12.58  14.88  12.55  13.42
# 2  Sep-05  13.48  14.87  12.27  13.30
# 3  Oct-05  13.20  14.47  12.40  12.99
# 4  Nov-05  13.35  13.88  12.88  13.41

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 185
# Number of Columns: 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    object
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

duplicate_count = df.duplicated().sum()
print(f"Duplicate values count :{duplicate_count}")
# Out:
# Duplicate values count :0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

missing_values = df.isnull().sum()

missing_values
# Out:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
# Visualizing the missing values

missing_values = df.isnull().sum()

if missing_values.sum() == 0:
    print("No missing values found in the dataset.")
else:
    missing_values.plot(kind='bar')
    plt.title('Missing Values in YES Bank Stock Dataset')
    plt.xlabel('Columns')
    plt.ylabel('Number of Missing Values')
    plt.show()
# Out:
# No missing values found in the dataset.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains historical monthly stock price information of YES Bank. It consists of 185 observations and 5 variables: Date, Open, High, Low, and Close.
#
# The Date column represents the time period of each stock price observation. Open represents the opening stock price, High represents the highest stock price recorded during the month, Low represents the lowest stock price, and Close represents the final closing stock price.
#
# The dataset contains numerical stock price variables that can be used to analyze historical price movements, trends, volatility, and relationships among different stock price features. The Close variable is particularly important because it represents the final market price of the stock for each period.
#
# The dataset was examined for missing values and duplicate records to ensure data quality before performing further exploratory data analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# Dataset Describe

df.describe()
# Out:
#              Open        High         Low       Close
# count  185.000000  185.000000  185.000000  185.000000
# mean   105.541405  116.104324   94.947838  105.204703
# std     98.879850  106.333497   91.219415   98.583153
# min     10.000000   11.240000    5.550000    9.980000
# 25%     33.800000   36.140000   28.510000   33.450000
# 50%     62.980000   72.550000   58.000000   62.540000
# 75%    153.000000  169.190000  138.350000  153.300000
# max    369.950000  404.000000  345.500000  367.900000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains five variables: Date, Open, High, Low, and Close. Date represents the month and year of the stock price observation. Open represents the opening stock price, High represents the highest stock price recorded during the month, Low represents the lowest stock price recorded during the month, and Close represents the final closing stock price of YES Bank for that month. The Close variable is the main target of analysis, while Open, High, and Low help in understanding stock price movements and market behavior.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

for column in df.columns:
    print(f"\nUnique values in {column}:")
    print(df[column].unique())
# Out:
# Unique values in Date:
# ['Jul-05' 'Aug-05' 'Sep-05' 'Oct-05' 'Nov-05' 'Dec-05' 'Jan-06' 'Feb-06'
#  'Mar-06' 'Apr-06' 'May-06' 'Jun-06' 'Jul-06' 'Aug-06' 'Sep-06' 'Oct-06'
#  'Nov-06' 'Dec-06' 'Jan-07' 'Feb-07' 'Mar-07' 'Apr-07' 'May-07' 'Jun-07'
#  'Jul-07' 'Aug-07' 'Sep-07' 'Oct-07' 'Nov-07' 'Dec-07' 'Jan-08' 'Feb-08'
#  'Mar-08' 'Apr-08' 'May-08' 'Jun-08' 'Jul-08' 'Aug-08' 'Sep-08' 'Oct-08'
#  'Nov-08' 'Dec-08' 'Jan-09' 'Feb-09' 'Mar-09' 'Apr-09' 'May-09' 'Jun-09'
#  'Jul-09' 'Aug-09' 'Sep-09' 'Oct-09' 'Nov-09' 'Dec-09' 'Jan-10' 'Feb-10'
#  'Mar-10' 'Apr-10' 'May-10' 'Jun-10' 'Jul-10' 'Aug-10' 'Sep-10' 'Oct-10'
#  'Nov-10' 'Dec-10' 'Jan-11' 'Feb-11' 'Mar-11' 'Apr-11' 'May-11' 'Jun-11'
#  'Jul-11' 'Aug-11' 'Sep-11' 'Oct-11' 'Nov-11' 'Dec-11' 'Jan-12' 'Feb-12'
#  'Mar-12' 'Apr-12' 'May-12' 'Jun-12' 'Jul-12' 'Aug-12' 'Sep-12' 'Oct-12'
#  'Nov-12' 'Dec-12' 'Jan-13' 'Feb-13' 'Mar-13' 'Apr-13' 'May-13' 'Jun-13'
#  'Jul-13' 'Aug-13' 'Sep-13' 'Oct-13' 'Nov-13' 'Dec-13' 'Jan-14' 'Feb-14'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready

# Convert Date column to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%b-%y')

# Sort the dataset chronologically
df = df.sort_values(by='Date').reset_index(drop=True)

# Verify the cleaned dataset
print(df.info())

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    datetime64[ns]
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 7.4 KB
# None
#         Date   Open   High    Low  Close
# 0 2005-07-01  13.00  14.00  11.25  12.46
# 1 2005-08-01  12.58  14.88  12.55  13.42
# 2 2005-09-01  13.48  14.87  12.27  13.30
# 3 2005-10-01  13.20  14.47  12.40  12.99
# 4 2005-11-01  13.35  13.88  12.88  13.41

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The dataset was examined for duplicate records and missing values. No duplicate rows or missing values were found, indicating that the dataset was already complete and consistent. The Date column was converted into datetime format to enable proper time-based analysis and the observations were arranged in chronological order. The dataset contains numerical stock price variables including Open, High, Low, and Close. These variables represent the monthly price movements of YES Bank stock. The cleaned and structured dataset is suitable for exploratory data analysis and visualization of historical stock price trends, volatility, and relationships between stock price variables.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Chart - 1: Closing Price Trend Over Time

plt.figure(figsize=(12, 6))

plt.plot(df['Date'], df['Close'])

plt.title('YES Bank Closing Price Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was selected because the dataset contains time-series stock price data. It helps visualize the movement and trend of YES Bank's closing price over time and makes it easier to identify periods of growth, decline, and fluctuations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows significant fluctuations in the closing price of YES Bank stock over the observed period. The stock experienced periods of strong growth followed by major declines. This indicates high volatility and changing market conditions affecting the stock price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the closing price trend can create a positive business impact by helping investors and analysts identify long-term stock price movements and make informed investment decisions. Periods of increasing closing prices indicate positive stock growth. However, the chart also shows periods of significant decline in closing prices, which indicate negative growth because the market value of the stock decreased continuously during those periods.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Chart - 2: Distribution of Closing Price

plt.figure(figsize=(10, 6))

sns.histplot(df['Close'], bins=20, kde=True)

plt.title('Distribution of YES Bank Closing Price')
plt.xlabel('Closing Price')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was selected to understand the frequency distribution of YES Bank's closing prices. It helps identify the common price ranges, spread of values, and the overall shape of the closing price distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution shows that the closing prices are not evenly distributed across all price ranges. A large number of observations are concentrated in lower and middle price ranges, while relatively fewer observations occur at very high closing prices. This indicates variation in the historical price behavior of the stock.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the distribution of closing prices can help investors identify the common price range of the stock and evaluate historical price behavior. This supports better investment and risk analysis. However, a concentration of observations at lower closing price levels may indicate periods of negative growth because the stock remained at reduced market valuations for a considerable period.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Chart - 3: Opening Price vs Closing Price

plt.figure(figsize=(10, 6))

plt.scatter(df['Open'], df['Close'])

plt.title('Opening Price vs Closing Price')
plt.xlabel('Opening Price')
plt.ylabel('Closing Price')

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was selected to examine the relationship between the opening price and closing price of YES Bank stock. It helps determine whether changes in the opening price are associated with changes in the closing price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows a strong positive relationship between opening and closing prices. As the opening price increases, the closing price generally also increases. The points are closely distributed along an upward trend, indicating a strong association between these two variables.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the strong relationship between opening and closing prices can support stock price analysis and predictive modeling, creating a positive business impact. Higher opening prices are generally associated with higher closing prices. However, when the closing price is lower than the opening price, it indicates a decline during the trading period. Repeated occurrences of such price declines may represent negative growth and selling pressure.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Chart - 4: High Price vs Low Price

plt.figure(figsize=(10, 6))

plt.scatter(df['Low'], df['High'])

plt.title('High Price vs Low Price')
plt.xlabel('Low Price')
plt.ylabel('High Price')

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was selected to analyze the relationship between the monthly high and low stock prices. This chart helps understand how the highest and lowest prices move together and provides information about the stock's price range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart indicates a strong positive relationship between the high and low stock prices. When the low price increases, the high price also generally increases. The relationship shows that both variables move together according to the overall market price level of YES Bank stock.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, analyzing High and Low prices can help investors understand stock price movement and market volatility, supporting better risk-based investment decisions. A higher price range may provide trading opportunities. However, a significant decline in both High and Low prices can indicate negative growth because the entire stock price range is shifting toward lower market values.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Chart - 5: Monthly Price Range

df['Price_Range'] = df['High'] - df['Low']

plt.figure(figsize=(12, 6))

plt.plot(df['Date'], df['Price_Range'])

plt.title('YES Bank Monthly Price Range Over Time')
plt.xlabel('Date')
plt.ylabel('Price Range (High - Low)')

plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was selected to analyze changes in the monthly price range of YES Bank stock over time. The price range was calculated as the difference between the monthly high and low prices and provides an indication of stock price volatility.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the monthly price range varies considerably over time. Some periods have a large difference between high and low prices, indicating high volatility, while other periods show smaller price ranges and relatively stable price movements.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, analyzing the monthly price range can help investors identify periods of high and low volatility and improve risk management decisions. Stable price ranges may support more predictable stock analysis. However, an extremely large monthly price range indicates high volatility and market uncertainty. If high volatility occurs along with declining closing prices, it may specifically indicate negative growth and increased investment risk.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Chart - 6: Comparison of Stock Prices Over Time

plt.figure(figsize=(12, 6))

plt.plot(df['Date'], df['Open'], label='Open')
plt.plot(df['Date'], df['High'], label='High')
plt.plot(df['Date'], df['Low'], label='Low')
plt.plot(df['Date'], df['Close'], label='Close')

plt.title('YES Bank Stock Price Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Stock Price')

plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A multiple line chart was selected to compare the Open, High, Low, and Close prices of YES Bank stock over time. It provides a complete view of historical stock price movements and helps identify whether all major price variables follow similar trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that Open, High, Low, and Close prices generally move in a similar direction over time. Significant growth and decline periods are visible across all four stock price variables. The difference between High and Low prices also varies across time, indicating changing levels of stock price volatility.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can create a positive business impact by helping investors and financial analysts understand overall stock price movements and identify periods of consistent price growth. Similar upward movements in Open, High, Low, and Close prices may indicate positive market performance. However, the chart also identifies periods of negative growth where all stock prices decline sharply. Such simultaneous declines may indicate weak investor confidence, adverse market conditions, or financial uncertainty and can increase investment risk.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Chart - 7: Correlation Heatmap

plt.figure(figsize=(8, 6))

correlation_matrix = df[['Open', 'High', 'Low', 'Close']].corr()

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Between YES Bank Stock Price Variables')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was selected to measure and visualize the strength of relationships between Open, High, Low, and Close stock prices. The heatmap makes it easy to identify strongly correlated numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows a very strong positive correlation between Open, High, Low, and Close prices. This indicates that the stock price variables generally move together. In particular, High, Low, and Open prices have a strong relationship with the closing price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can create a positive business impact because strongly correlated price variables can support stock price analysis and predictive model development. Open, High, and Low prices can provide useful information for estimating closing price movements. However, a negative growth signal can occur when these highly correlated variables decline together. Since the variables move in a similar direction, a simultaneous decrease may indicate an overall downward stock trend and increased financial risk.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Chart - 8: Yearly Average Closing Price

df['Year'] = df['Date'].dt.year

yearly_close = df.groupby('Year')['Close'].mean()

plt.figure(figsize=(12, 6))

yearly_close.plot(kind='bar')

plt.title('Yearly Average Closing Price of YES Bank Stock')
plt.xlabel('Year')
plt.ylabel('Average Closing Price')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was selected to compare the average closing price of YES Bank stock across different years. It provides a clear year-wise comparison and helps identify long-term periods of growth and decline.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows considerable variation in the average closing price across different years. Some years experienced higher average stock prices, indicating periods of stronger stock performance, while other years show significant reductions in the average closing price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact by helping investors and financial analysts identify historically strong-performing years and understand long-term stock price trends. Years with increasing average closing prices indicate positive growth and stronger market valuation. However, a substantial reduction in the yearly average closing price represents negative growth because it indicates a sustained decline in stock value and may reflect reduced investor confidence or unfavorable market conditions.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Chart - 9: Monthly Percentage Change in Closing Price

df['Close_Pct_Change'] = df['Close'].pct_change() * 100

plt.figure(figsize=(12, 6))

plt.plot(df['Date'], df['Close_Pct_Change'])

plt.axhline(y=0, linestyle='--')

plt.title('Monthly Percentage Change in YES Bank Closing Price')
plt.xlabel('Date')
plt.ylabel('Percentage Change (%)')

plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was selected to analyze the monthly percentage change in YES Bank's closing price. Percentage change helps measure the rate of stock price growth or decline between consecutive months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows both positive and negative monthly percentage changes in the closing price. Positive values represent months of stock price growth, while negative values indicate declining stock prices. Large fluctuations in percentage change also indicate periods of high market volatility.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact by helping investors identify months with positive stock price growth and evaluate the historical momentum of the stock. Consistent positive percentage changes may indicate improving market performance. However, large negative percentage changes directly represent negative growth because the closing price has fallen compared with the previous month. Repeated negative changes may indicate a sustained downward trend and increased investment risk.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Chart - 10: Closing Price Box Plot

plt.figure(figsize=(8, 6))

sns.boxplot(y=df['Close'])

plt.title('Box Plot of YES Bank Closing Price')
plt.ylabel('Closing Price')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was selected to analyze the distribution, spread, median, and potential outliers in YES Bank's closing prices. It provides a compact statistical view of historical closing price behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot shows the central distribution and variability of the closing prices. The wide spread of values indicates considerable variation in YES Bank's historical stock price. Extreme values outside the typical price range may represent periods of unusually high or low stock valuation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact by helping financial analysts understand the normal historical price range and identify unusual stock price movements. Higher extreme values may represent periods of strong market valuation and positive growth. However, unusually low closing prices can indicate negative growth because they represent significant reductions in stock value. A wide price spread also indicates greater historical volatility, which may increase investment risk.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Chart - 11: High Price vs Closing Price

plt.figure(figsize=(8, 6))

plt.scatter(df['High'], df['Close'], alpha=0.7)

plt.title('High Price vs Closing Price')
plt.xlabel('High Price')
plt.ylabel('Closing Price')

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was selected to analyze the relationship between the High price and Closing price of YES Bank stock. It helps identify the strength and direction of the relationship between these two numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows a strong positive relationship between the High price and Closing price. As the High price increases, the Closing price also generally increases. The points follow a clear upward pattern, indicating that the High price is strongly associated with the final monthly Closing price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insight can create a positive business impact because the High price can be used as an important indicator for analyzing and predicting the Closing price. An increasing High price associated with an increasing Closing price may indicate positive stock performance. However, a decline in the High price accompanied by a lower Closing price can indicate negative growth because the stock is unable to achieve higher market valuations and is closing at reduced price levels.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Chart - 12: Low Price vs Closing Price

plt.figure(figsize=(8, 6))

plt.scatter(df['Low'], df['Close'], alpha=0.7)

plt.title('Low Price vs Closing Price')
plt.xlabel('Low Price')
plt.ylabel('Closing Price')

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was selected to examine the relationship between the Low price and Closing price. This chart helps determine whether changes in the lowest monthly stock price are associated with changes in the final Closing price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart indicates a strong positive relationship between the Low price and Closing price. Higher Low prices are generally associated with higher Closing prices. This suggests that the monthly Low price is an important variable for understanding Closing price behavior.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insight can support positive business impact by helping investors and analysts evaluate stock price strength. A rising Low price combined with a rising Closing price may indicate stronger price support and positive stock growth. However, continuously decreasing Low prices may indicate negative growth because the stock is reaching lower valuation levels. If the Closing price also declines, it may indicate weakening market performance and increased investment risk.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Chart - 13: Monthly Price Range Over Time

df['Price_Range'] = df['High'] - df['Low']

plt.figure(figsize=(12, 6))

plt.plot(df['Date'], df['Price_Range'])

plt.title('Monthly Price Range of YES Bank Stock')
plt.xlabel('Date')
plt.ylabel('Price Range (High - Low)')

plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was selected to analyze the monthly price range calculated as the difference between the High and Low stock prices. The price range provides information about historical stock price volatility.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the monthly price range varies considerably over time. Some periods have a large difference between High and Low prices, indicating high volatility, while other periods show smaller price ranges and relatively stable stock price movements.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can create a positive business impact by helping investors identify stable and highly volatile market periods and make risk-aware financial decisions. A moderate and stable price range may support more predictable stock analysis. However, extremely large price ranges can represent a negative business signal because high volatility indicates market uncertainty and greater investment risk. If high volatility occurs together with declining Closing prices, it may specifically indicate negative stock growth and strong selling pressure.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Chart - 14: Correlation Heatmap

plt.figure(figsize=(10, 6))

correlation_matrix = df[
    ['Open', 'High', 'Low', 'Close']
].corr()

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Heatmap of Stock Price Variables')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was selected to visualize the strength and direction of relationships between the numerical stock price variables Open, High, Low, and Close. It provides a clear and concise representation of the correlation coefficients between multiple variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The correlation heatmap shows a strong positive correlation among Open, High, Low, and Close prices. This indicates that these stock price variables generally move in the same direction. In particular, the closing price has a strong relationship with the opening, high, and low prices, showing that these variables are closely associated with the overall stock price movement.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Chart - 15: Pair Plot of Stock Price Variables

sns.pairplot(
    df[['Open', 'High', 'Low', 'Close']]
)

plt.suptitle(
    'Pairwise Relationships Between Stock Price Variables',
    y=1.02
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot was selected to perform multivariate analysis of Open, High, Low, and Close stock prices. It simultaneously visualizes the distributions and pairwise relationships between multiple numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot shows strong positive relationships among Open, High, Low, and Close prices. Most scatter plots display a clear upward linear pattern, indicating that the stock price variables move together. The diagonal distribution plots also show the historical distribution of each stock price variable.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the exploratory data analysis of YES Bank stock prices, the client should use historical Open, High, Low, and Close price patterns to understand stock price movements, volatility, and long-term trends. The analysis shows strong relationships among the major stock price variables, indicating that these variables can provide valuable information for stock price analysis and forecasting.
#
# The client should continuously monitor closing price trends and monthly price ranges to identify periods of positive growth, declining prices, and high market volatility. Large differences between High and Low prices should be considered as indicators of increased market uncertainty and investment risk.
#
# The strong correlation between Open, High, Low, and Close prices can also be utilized for developing machine learning-based stock price prediction models. Historical price patterns and trend analysis can support data-driven financial decisions and improve risk assessment.
#
# Therefore, the client is recommended to combine historical trend analysis, volatility monitoring, and predictive analytics to support informed investment and stock market decision-making. However, stock price predictions should also consider external market conditions and financial factors because historical stock prices alone cannot completely represent future market behavior.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Exploratory Data Analysis of the YES Bank stock price dataset provided valuable insights into historical stock price movements, trends, distributions, volatility, and relationships among different price variables.
#
# The dataset was examined for its structure, duplicate records, and missing values before performing the analysis. The Open, High, Low, and Close price variables were analyzed using univariate, bivariate, and multivariate visualizations. The closing price trend showed significant variations in the historical market value of YES Bank stock, including periods of growth and decline.
#
# The analysis of opening and closing prices demonstrated a strong relationship between the initial and final stock prices of a trading period. High and Low price analysis provided insights into stock price ranges and market volatility. The correlation analysis further showed strong positive relationships among Open, High, Low, and Close prices, indicating that these variables generally move together.
#
# The visualizations also identified periods of high volatility and declining stock prices that may indicate increased market risk and negative growth. These insights can support investors and financial analysts in understanding historical stock behavior, identifying price trends, and improving risk assessment.
#
# Overall, the EDA successfully achieved the business objective of understanding the historical price behavior of YES Bank stock. The insights obtained from the analysis can support data-driven financial decision-making and can serve as a foundation for developing machine learning-based stock closing price prediction models.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
